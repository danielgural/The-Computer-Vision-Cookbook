# %%
# !pip install -U sahi ultralytics huggingface_hub --quiet
# Out:
# DEPRECATION: pytorch-lightning 1.5.4 has a non-standard dependency specifier torch>=1.7.*. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pytorch-lightning or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %%
import fiftyone as fo
import fiftyone.zoo as foz
import fiftyone.utils.huggingface as fouh
from fiftyone import ViewField as F

# %%
dataset = fouh.load_from_hub("jamarks/VisDrone2019-DET", name="sahi-test", max_samples=100, overwrite=True)
# Out:
# Downloading config file fiftyone.yml from jamarks/VisDrone2019-DET
# fiftyone.yml:   0%|          | 0.00/113 [00:00<?, ?B/s]
# Loading dataset
# Importing samples...
#  100% |█████████████████| 100/100 [33.5ms elapsed, 0s remaining, 3.0K samples/s]
# Downloading 100 media files...

# %%
session = fo.launch_app(dataset)
# Out:
# Connected to FiftyOne on port 5151 at localhost.
# If you are not connecting to a remote session, you may need to start a new session and specify a port
# <style>
# @import url("https://fonts.googleapis.com/css2?family=Palanquin&display=swap");
#
# body, html {
#   margin: 0;
#   padding: 0;
#   width: 100%;
# }
#
# #focontainer-f001ed94-65e1-4455-a079-f9d90fdf38c9 {
#   position: relative;
#   height: 800px;
#   display: block !important;
# }
# #foactivate-f001ed94-65e1-4455-a079-f9d90fdf38c9 {
#   font-weight: bold;
#   cursor: pointer;
#   font-size: 24px;
#   border-radius: 3px;
#   text-align: center;
#   padding: 0.5em;
#   color: rgb(255, 255, 255);
#   font-family: "Palanquin", sans-serif;
#   position: absolute;
#   left: 50%;
#   top: 50%;
#   width: 160px;
#   margin-left: -80px;
#   margin-top: -23px;
#   background: hsla(210,11%,15%, 0.8);
#   border: none;
# }
# #foactivate-f001ed94-65e1-4455-a079-f9d90fdf38c9:focus {
#   outline: none;
# }
# #fooverlay-f001ed94-65e1-4455-a079-f9d90fdf38c9 {
#   width: 100%;
#   height: 100%;
#   background: hsla(208, 7%, 46%, 0.7);
#   position: absolute;
#   top: 0;
#   left: 0;
#   display: none;
#   cursor: pointer;
# }
# </style>
#
# <div id="focontainer-f001ed94-65e1-4455-a079-f9d90fdf38c9">
#    <div id="fooverlay-f001ed94-65e1-4455-a079-f9d90fdf38c9" style="display: none;">
#       <button id="foactivate-f001ed94-65e1-4455-a079-f9d90fdf38c9" >Activate</button>
#    </div>
#    <img src='data:image/jpeg;base64,...' style="width: 100%; max-width: 1061px;"/>
# </div>
#
# <script type="text/javascript">
#    (function() {
#      var container = document.getElementById("focontainer-f001ed94-65e1-4455-a079-f9d90fdf38c9");
#      var overlay = document.getElementById("fooverlay-f001ed94-65e1-4455-a079-f9d90fdf38c9");
#      fetch(`http://localhost:5151/fiftyone`)
#      .then(() => {
#         overlay.addEventListener("click", () => {
#           fetch(`http://localhost:5151/event`, {
#             method: "POST",
#             body: JSON.stringify({
#               event: "reactivate_notebook_cell",
#               data: { subscription: "f001ed94-65e1-4455-a079-f9d90fdf38c9" },
#               subscription: "f001ed94-65e1-4455-a079-f9d90fdf38c9"
#             })
#           })
#         });
#         container.addEventListener("mouseenter", () => overlay.style.display = "block");
#         container.addEventListener("mouseleave", () => overlay.style.display = "none");
#      });
#    })();
# </script>

# %%
from ultralytics import YOLO

ckpt_path = "yolov8l.pt"
model = YOLO(ckpt_path)
## fiftyone will work directly with the Ultralytics.YOLO model

dataset.apply_model(model, label_field="base_model")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8l.pt to 'yolov8l.pt'...
# 100%|██████████| 83.7M/83.7M [00:03<00:00, 26.1MB/s]
#  100% |█████████████████| 100/100 [7.3s elapsed, 0s remaining, 15.7 samples/s]

# %%
session = fo.launch_app(dataset)
# Out:
# <style>
# @import url("https://fonts.googleapis.com/css2?family=Palanquin&display=swap");
#
# body, html {
#   margin: 0;
#   padding: 0;
#   width: 100%;
# }
#
# #focontainer-b1dd75a3-f3ff-4f23-904e-19541249cc77 {
#   position: relative;
#   height: 800px;
#   display: block !important;
# }
# #foactivate-b1dd75a3-f3ff-4f23-904e-19541249cc77 {
#   font-weight: bold;
#   cursor: pointer;
#   font-size: 24px;
#   border-radius: 3px;
#   text-align: center;
#   padding: 0.5em;
#   color: rgb(255, 255, 255);
#   font-family: "Palanquin", sans-serif;
#   position: absolute;
#   left: 50%;
#   top: 50%;
#   width: 160px;
#   margin-left: -80px;
#   margin-top: -23px;
#   background: hsla(210,11%,15%, 0.8);
#   border: none;
# }
# #foactivate-b1dd75a3-f3ff-4f23-904e-19541249cc77:focus {
#   outline: none;
# }
# #fooverlay-b1dd75a3-f3ff-4f23-904e-19541249cc77 {
#   width: 100%;
#   height: 100%;
#   background: hsla(208, 7%, 46%, 0.7);
#   position: absolute;
#   top: 0;
#   left: 0;
#   display: none;
#   cursor: pointer;
# }
# </style>
#
# <div id="focontainer-b1dd75a3-f3ff-4f23-904e-19541249cc77">
#    <div id="fooverlay-b1dd75a3-f3ff-4f23-904e-19541249cc77" style="display: none;">
#       <button id="foactivate-b1dd75a3-f3ff-4f23-904e-19541249cc77" >Activate</button>
#    </div>
#    <img src='data:image/jpeg;base64,...' style="width: 100%; max-width: 1061px;"/>
# </div>
#
# <script type="text/javascript">
#    (function() {
#      var container = document.getElementById("focontainer-b1dd75a3-f3ff-4f23-904e-19541249cc77");
#      var overlay = document.getElementById("fooverlay-b1dd75a3-f3ff-4f23-904e-19541249cc77");
#      fetch(`http://localhost:5151/fiftyone`)
#      .then(() => {
#         overlay.addEventListener("click", () => {
#           fetch(`http://localhost:5151/event`, {
#             method: "POST",
#             body: JSON.stringify({
#               event: "reactivate_notebook_cell",
#               data: { subscription: "b1dd75a3-f3ff-4f23-904e-19541249cc77" },
#               subscription: "b1dd75a3-f3ff-4f23-904e-19541249cc77"
#             })
#           })
#         });
#         container.addEventListener("mouseenter", () => overlay.style.display = "block");
#         container.addEventListener("mouseleave", () => overlay.style.display = "none");
#      });
#    })();
# </script>

# %%
mapping = {"pedestrians": "person", "people": "person", "van": "car"}
mapped_view = dataset.map_labels("ground_truth", mapping)

# %%
def get_label_fields(sample_collection):
    """Get the (detection) label fields of a Dataset or DatasetView."""
    label_fields = list(
        sample_collection.get_field_schema(embedded_doc_type=fo.Detections).keys()
    )
    return label_fields

def filter_all_labels(sample_collection):
    label_fields = get_label_fields(sample_collection)

    filtered_view = sample_collection

    for lf in label_fields:
        filtered_view = filtered_view.filter_labels(
            lf, F("label").is_in(["person", "car", "truck"]), only_matches=False
        )
    return filtered_view

# %%
filtered_view = filter_all_labels(mapped_view)

# %%
session.view = filtered_view.view()
# Out:
#         <iframe
#             width="100%"
#             height="800"
#             src="http://localhost:5151/?notebook=True&subscription=a34a5a43-1955-4a15-9ea0-16993e02e2fa"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
from sahi import AutoDetectionModel
from sahi.predict import get_prediction, get_sliced_prediction

# %%
detection_model = AutoDetectionModel.from_pretrained(
    model_type='yolov8',
    model_path=ckpt_path,
    confidence_threshold=0.25, ## same as the default value for our base model
    image_size=640,
    device="cpu", # or 'cuda'
)

# %%
result = get_prediction(dataset.first().filepath, detection_model, verbose=0)
print(result)
# Out:
# <sahi.prediction.PredictionResult object at 0x741938980eb0>

# %%
print(result.to_fiftyone_detections())
# Out:
# [<Detection: {
#     'id': '663c3d12ebcc6fc2030a2250',
#     'attributes': {},
#     'tags': [],
#     'label': 'car',
#     'bounding_box': [
#         0.6646394729614258,
#         0.7850866247106482,
#         0.06464214324951172,
#         0.09088355170355902,
#     ],
#     'mask': None,
#     'confidence': 0.8933133482933044,
#     'index': None,
# }>, <Detection: {
#     'id': '663c3d12ebcc6fc2030a2251',
#     'attributes': {},
#     'tags': [],
#     'label': 'car',
#     'bounding_box': [
#         0.6196376800537109,
#         0.7399617513020833,
#         0.06670347849527995,
#         0.09494832356770834,
#     ],
#     'mask': None,
#     'confidence': 0.8731603622436523,
#     'index': None,
# }>, <Detection: {
#     'id': '663c3d12ebcc6fc2030a2252',
#     'attributes': {},
#     'tags': [],
#     'label': 'car',
#     'bounding_box': [
#         0.5853352228800456,
#         0.7193766276041667,
#         0.06686935424804688,
#         0.07682359483506944,
#     ],
#     'mask': None,
#     'confidence': 0.859582781791687,
#     'index': None,
# }>, <Detection: {
#     'id': '663c3d12ebcc6fc2030a2253',
#     'attributes': {},
#     'tags': [],
#     'label': 'car',
#     'bounding_box': [
#         0.5635160446166992,
#         0.686444091796875,
#         0.06365642547607422,
#         0.06523607042100694,
#     ],
#     'mask': None,
#     'confidence': 0.8547812104225159,
#     'index': None,
# }>, <Detection: {
#     'id': '663c3d12ebcc6fc2030a2254',
#     'attributes': {},
#     'tags': [],
#     'label': 'car',
#     'bounding_box': [
#         0.7365047454833984,
#         0.8709894816080729,
#         0.07815799713134766,
#         0.06583930121527778,
#     ],
#     'mask': None,
#     'confidence': 0.8482969403266907,
#     'index': None,
# }>, <Detection: {
#     'id': '663c3d12ebcc6fc2030a2255',
#     'attributes': {},
#     'tags': [],
#     'label': 'car',
#     'bounding_box': [
#         0.4387975692749023,
#         0.7973368326822917,
#         0.07478656768798828,
#         0.08685709635416666,
#     ],
#     'mask': None,
#     'confidence': 0.8482540845870972,
#     'index': None,
# }>, <Detection: {
#     'id': '663c3d12ebcc6fc2030a2256',
#     'attributes': {},
#     'tags': [],
#     'label': 'car',
#     'bounding_box': [
#         0.4144182523091634,
#         0.7553463971173322,
#         0.07797966003417969,
#         0.09232432047526042,
#     ],
#     'mask': None,
#     'confidence': 0.8444774150848389,
#     'index': None,
# }>, <Detection: {
#     'id': '663c3d12ebcc6fc2030a2257',
#     'attributes': {},
#     'tags': [],
#     'label': 'car',
#     'bounding_box': [
#         0.4094355583190918,
#         0.7256359524197049,
#         0.07238206863403321,
#         0.07048272026909722,
#     ],
#     'mask': None,
#     'confidence': 0.798665463924408,
#     'index': None,
# }>, <Detection: {
#     'id': '663c3d12ebcc6fc2030a2258',
#     'attributes': {},
#     'tags': [],
#     'label': 'car',
#     'bounding_box': [
#         0.5339123407999674,
#         0.6121688842773437,
#         0.07190316518147787,
#         0.07292723479094329,
#     ],
#     'mask': None,
#     'confidence': 0.7936849594116211,
#     'index': None,
# }>, <Detection: {
#     'id': '663c3d12ebcc6fc2030a2259',
#     'attributes': {},
#     'tags': [],
#     'label': 'car',
#     'bounding_box': [
#         0.03444666862487793,
#         0.5164913601345487,
#         0.03219947814941406,
#         0.06044170238353588,
#     ],
#     'mask': None,
#     'confidence': 0.7404834032058716,
#     'index': None,
# }>, <Detection: {
#     'id': '663c3d12ebcc6fc2030a225a',
#     'attributes': {},
#     'tags': [],
#     'label': 'car',
#     'bounding_box': [
#         0.3923538525899251,
#         0.6745626378942419,
#         0.06798810958862304,
#         0.07528584798177083,
#     ],
#     'mask': None,
#     'confidence': 0.6714915633201599,
#     'index': None,
# }>, <Detection: {
#     'id': '663c3d12ebcc6fc2030a225b',
#     'attributes': {},
#     'tags': [],
#     'label': 'car',
#     'bounding_box': [
#         0.5216399192810058,
#         0.5886645846896701,
#         0.06560036341349283,
#         0.059334818522135416,
#     ],
#     'mask': None,
#     'confidence': 0.664937436580658,
#     'index': None,
# }>, <Detection: {
#     'id': '663c3d12ebcc6fc2030a225c',
#     'attributes': {},
#     'tags': [],
#     'label': 'car',
#     'bounding_box': [
#         0.5096873283386231,
#         0.5273054334852431,
#         0.0551149050394694,
#         0.07670678032769097,
#     ],
#     'mask': None,
#     'confidence': 0.6273285150527954,
#     'index': None,
# }>, <Detection: {
#     'id': '663c3d12ebcc6fc2030a225d',
#     'attributes': {},
#     'tags': [],
#     'label': 'car',
#     'bounding_box': [
#         0.37222995758056643,
#         0.5739803738064236,
#         0.06103067398071289,
#         0.06263710304542824,
#     ],
#     'mask': None,
#     'confidence': 0.5973837375640869,
#     'index': None,
# }>, <Detection: {
#     'id': '663c3d12ebcc6fc2030a225e',
#     'attributes': {},
#     'tags': [],
#     'label': 'car',
#     'bounding_box': [
#         0.05044105052947998,
#         0.44830712212456597,
#         0.02773451805114746,
#         0.054146491156684025,
#     ],
#     'mask': None,
#     'confidence': 0.5668565034866333,
#     'index': None,
# }>, <Detection: {
#     'id': '663c3d12ebcc6fc2030a225f',
#     'attributes': {},
#     'tags': [],
#     'label': 'car',
#     'bounding_box': [
#         0.38649218877156577,
#         0.6419422290943287,
#         0.0629791259765625,
#         0.05787251790364583,
#     ],
#     'mask': None,
#     'confidence': 0.525835394859314,
#     'index': None,
# }>, <Detection: {
#     'id': '663c3d12ebcc6fc2030a2260',
#     'attributes': {},
#     'tags': [],
#     'label': 'car',
#     'bounding_box': [
#         3.7077069282531736e-05,
#         0.5483550460250289,
#         0.027724575996398926,
#         0.06541680230034722,
#     ],
#     'mask': None,
#     'confidence': 0.5090424418449402,
#     'index': None,
# }>, <Detection: {
#     'id': '663c3d12ebcc6fc2030a2261',
#     'attributes': {},
#     'tags': [],
#     'label': 'car',
#     'bounding_box': [
#         0.08821650346120198,
#         0.23074938456217448,
#         0.01933759848276774,
#         0.03344725149649161,
#     ],
#     'mask': None,
#     'confidence': 0.49806371331214905,
#     'index': None,
# }>, <Detection: {
#     'id': '663c3d12ebcc6fc2030a2262',
#     'attributes': {},
#     'tags': [],
#     'label': 'car',
#     'bounding_box': [
#         0.17596534093221028,
#         0.20812852647569444,
#         0.017548131942749023,
#         0.027273390028211806,
#     ],
#     'mask': None,
#     'confidence': 0.4398653209209442,
#     'index': None,
# }>, <Detection: {
#     'id': '663c3d12ebcc6fc2030a2263',
#     'attributes': {},
#     'tags': [],
#     'label': 'car',
#     'bounding_box': [
#         0.10628087520599365,
#         0.1506349351671007,
#         0.014339685440063477,
#         0.02781194051106771,
#     ],
#     'mask': None,
#     'confidence': 0.3908688426017761,
#     'index': None,
# }>, <Detection: {
#     'id': '663c3d12ebcc6fc2030a2264',
#     'attributes': {},
#     'tags': [],
#     'label': 'person',
#     'bounding_box': [
#         0.04780056476593018,
#         0.7202997843424479,
#         0.015467214584350585,
#         0.04947526719835069,
#     ],
#     'mask': None,
#     'confidence': 0.3743867874145508,
#     'index': None,
# }>, <Detection: {
#     'id': '663c3d12ebcc6fc2030a2265',
#     'attributes': {},
#     'tags': [],
#     'label': 'person',
#     'bounding_box': [
#         0.0586588978767395,
#         0.6286194412796585,
#         0.011204906304677327,
#         0.04742550320095486,
#     ],
#     'mask': None,
#     'confidence': 0.3704468905925751,
#     'index': None,
# }>, <Detection: {
#     'id': '663c3d12ebcc6fc2030a2266',
#     'attributes': {},
#     'tags': [],
#     'label': 'person',
#     'bounding_box': [
#         0.2419193744659424,
#         0.42322124905056424,
#         0.011193466186523438,
#         0.04129248725043403,
#     ],
#     'mask': None,
#     'confidence': 0.3421861529350281,
#     'index': None,
# }>, <Detection: {
#     'id': '663c3d12ebcc6fc2030a2267',
#     'attributes': {},
#     'tags': [],
#     'label': 'car',
#     'bounding_box': [
#         0.4807417869567871,
#         0.48032887776692706,
#         0.05226335525512695,
#         0.05900353325737847,
#     ],
#     'mask': None,
#     'confidence': 0.3135659992694855,
#     'index': None,
# }>, <Detection: {
#     'id': '663c3d12ebcc6fc2030a2268',
#     'attributes': {},
#     'tags': [],
#     'label': 'car',
#     'bounding_box': [
#         0.2269471327463786,
#         0.6389475504557292,
#         0.020579051971435548,
#         0.060650182653356484,
#     ],
#     'mask': None,
#     'confidence': 0.30287665128707886,
#     'index': None,
# }>, <Detection: {
#     'id': '663c3d12ebcc6fc2030a2269',
#     'attributes': {},
#     'tags': [],
#     'label': 'person',
#     'bounding_box': [
#         0.055668628215789794,
#         0.5786148071289062,
#         0.010613775253295899,
#         0.03894076877170139,
#     ],
#     'mask': None,
#     'confidence': 0.2640884518623352,
#     'index': None,
# }>]

# %%
sliced_result = get_sliced_prediction(
    dataset.skip(40).first().filepath,
    detection_model,
    slice_height = 320,
    slice_width = 320,
    overlap_height_ratio = 0.2,
    overlap_width_ratio = 0.2,
)
# Out:
# Performing prediction on 8 number of slices.

# %%
num_sliced_dets = len(sliced_result.to_fiftyone_detections())
num_orig_dets = len(result.to_fiftyone_detections())

print(f"Detections predicted without slicing: {num_orig_dets}")
print(f"Detections predicted with slicing: {num_sliced_dets}")
# Out:
# Detections predicted without slicing: 26
# Detections predicted with slicing: 73

# %%
def predict_with_slicing(sample, label_field, **kwargs):
    result = get_sliced_prediction(
        sample.filepath, detection_model, verbose=0, **kwargs
    )
    sample[label_field] = fo.Detections(detections=result.to_fiftyone_detections())

# %%
kwargs = {"overlap_height_ratio": 0.2, "overlap_width_ratio": 0.2}

for sample in dataset.iter_samples(progress=True, autosave=True):
    predict_with_slicing(sample, label_field="small_slices", slice_height=320, slice_width=320, **kwargs)
    predict_with_slicing(sample, label_field="large_slices", slice_height=480, slice_width=480, **kwargs)
# Out:
#    1% |-----------------|   1/100 [2.1m elapsed, 3.4h remaining, 0.0 samples/s]
# 05/08/2024 23:06:42 - INFO - eta.core.utils -      1% |-----------------|   1/100 [2.1m elapsed, 3.4h remaining, 0.0 samples/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 5
#       3 for sample in dataset.iter_samples(progress=True, autosave=True):
#       4     predict_with_slicing(sample, label_field="small_slices", slice_height=320, slice_width=320, **kwargs)
# ----> 5     predict_with_slicing(sample, label_field="large_slices", slice_height=480, slice_width=480, **kwargs)
#
# Cell In[18], line 2, in predict_with_slicing(sample, label_field, **kwargs)
#       1 def predict_with_slicing(sample, label_field, **kwargs):
# ----> 2     result = get_sliced_prediction(
#       3         sample.filepath, detection_model, verbose=0, **kwargs
#       4     )
#       5     sample[label_field] = fo.Detections(detections=result.to_fiftyone_detections())
#
# File ~/anaconda3/envs/dev/lib/python3.9/site-packages/sahi/predict.py:241, in get_sliced_prediction(image, detection_model, slice_height, slice_width, overlap_height_ratio, overlap_width_ratio, perform_standard_pred, postprocess_type, postprocess_match_metric, postprocess_match_threshold, postprocess_class_agnostic, verbose, merge_buffer_length, auto_slice_resolution)
#     239     shift_amount_list.append(slice_image_result.starting_pixels[group_ind * num_batch + image_ind])
#     240 # perform batch prediction
# --> 241 prediction_result = get_prediction(
#     242     image=image_list[0],
#     243     detection_model=detection_model,
#     244     shift_amount=shift_amount_list[0],
#     245     full_shape=[
#     246         slice_image_result.original_image_height,
#     247         slice_image_result.original_image_width,
#     248     ],
#     249 )
#     250 # convert sliced predictions to full predictions
#     251 for object_prediction in prediction_result.object_prediction_list:
#
# File ~/anaconda3/envs/dev/lib/python3.9/site-packages/sahi/predict.py:93, in get_prediction(image, detection_model, shift_amount, full_shape, postprocess, verbose)
#      91 # get prediction
#      92 time_start = time.time()
# ---> 93 detection_model.perform_inference(np.ascontiguousarray(image_as_pil))
#      94 time_end = time.time() - time_start
#      95 durations_in_seconds["prediction"] = time_end
#
# File ~/anaconda3/envs/dev/lib/python3.9/site-packages/sahi/models/yolov8.py:61, in Yolov8DetectionModel.perform_inference(self, image)
#      59 if self.model is None:
#      60     raise ValueError("Model is not loaded, load it by calling .load_model()")
# ---> 61 prediction_result = self.model(image[:, :, ::-1], verbose=False)  # YOLOv8 expects numpy arrays to have BGR
#      62 prediction_result = [
#      63     result.boxes.data[result.boxes.data[:, 4] >= self.confidence_threshold] for result in prediction_result
#      64 ]
#      66 self._original_predictions = prediction_result
#
# File ~/anaconda3/envs/dev/lib/python3.9/site-packages/ultralytics/engine/model.py:176, in Model.__call__(self, source, stream, **kwargs)
#     153 def __call__(
#     154     self,
#     155     source: Union[str, Path, int, list, tuple, np.ndarray, torch.Tensor] = None,
#     156     stream: bool = False,
#     157     **kwargs,
#     158 ) -> list:
#     159     """
#     160     An alias for the predict method, enabling the model instance to be callable.
#     161
#    (...)
#     174         (List[ultralytics.engine.results.Results]): A list of prediction results, encapsulated in the Results class.
#     175     """
# --> 176     return self.predict(source, stream, **kwargs)
#
# File ~/anaconda3/envs/dev/lib/python3.9/site-packages/ultralytics/engine/model.py:452, in Model.predict(self, source, stream, predictor, **kwargs)
#     450 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     451     self.predictor.set_prompts(prompts)
# --> 452 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File ~/anaconda3/envs/dev/lib/python3.9/site-packages/ultralytics/engine/predictor.py:168, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     166     return self.stream_inference(source, model, *args, **kwargs)
#     167 else:
# --> 168     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File ~/anaconda3/envs/dev/lib/python3.9/site-packages/torch/utils/_contextlib.py:35, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      32 try:
#      33     # Issuing `None` to a generator fires it up
#      34     with ctx_factory():
# ---> 35         response = gen.send(None)
#      37     while True:
#      38         try:
#      39             # Forward the response to our caller and get its next request
#
# File ~/anaconda3/envs/dev/lib/python3.9/site-packages/ultralytics/engine/predictor.py:248, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     246 # Inference
#     247 with profilers[1]:
# --> 248     preds = self.inference(im, *args, **kwargs)
#     249     if self.args.embed:
#     250         yield from [preds] if isinstance(preds, torch.Tensor) else preds  # yield embedding tensors
#
# File ~/anaconda3/envs/dev/lib/python3.9/site-packages/ultralytics/engine/predictor.py:142, in BasePredictor.inference(self, im, *args, **kwargs)
#     136 """Runs inference on a given image using the specified model and arguments."""
#     137 visualize = (
#     138     increment_path(self.save_dir / Path(self.batch[0][0]).stem, mkdir=True)
#     139     if self.args.visualize and (not self.source_type.tensor)
#     140     else False
#     141 )
# --> 142 return self.model(im, augment=self.args.augment, visualize=visualize, embed=self.args.embed, *args, **kwargs)
#
# File ~/anaconda3/envs/dev/lib/python3.9/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/dev/lib/python3.9/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/anaconda3/envs/dev/lib/python3.9/site-packages/ultralytics/nn/autobackend.py:453, in AutoBackend.forward(self, im, augment, visualize, embed)
#     451 # PyTorch
#     452 if self.pt or self.nn_module:
# --> 453     y = self.model(im, augment=augment, visualize=visualize, embed=embed)
#     455 # TorchScript
#     456 elif self.jit:
#
# File ~/anaconda3/envs/dev/lib/python3.9/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/dev/lib/python3.9/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/anaconda3/envs/dev/lib/python3.9/site-packages/ultralytics/nn/tasks.py:89, in BaseModel.forward(self, x, *args, **kwargs)
#      87 if isinstance(x, dict):  # for cases of training and validating while training.
#      88     return self.loss(x, *args, **kwargs)
# ---> 89 return self.predict(x, *args, **kwargs)
#
# File ~/anaconda3/envs/dev/lib/python3.9/site-packages/ultralytics/nn/tasks.py:107, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#     105 if augment:
#     106     return self._predict_augment(x)
# --> 107 return self._predict_once(x, profile, visualize, embed)
#
# File ~/anaconda3/envs/dev/lib/python3.9/site-packages/ultralytics/nn/tasks.py:128, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     126 if profile:
#     127     self._profile_one_layer(m, x, dt)
# --> 128 x = m(x)  # run
#     129 y.append(x if m.i in self.save else None)  # save output
#     130 if visualize:
#
# File ~/anaconda3/envs/dev/lib/python3.9/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/dev/lib/python3.9/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/anaconda3/envs/dev/lib/python3.9/site-packages/ultralytics/nn/modules/block.py:230, in C2f.forward(self, x)
#     228 """Forward pass through C2f layer."""
#     229 y = list(self.cv1(x).chunk(2, 1))
# --> 230 y.extend(m(y[-1]) for m in self.m)
#     231 return self.cv2(torch.cat(y, 1))
#
# File ~/anaconda3/envs/dev/lib/python3.9/site-packages/ultralytics/nn/modules/block.py:230, in <genexpr>(.0)
#     228 """Forward pass through C2f layer."""
#     229 y = list(self.cv1(x).chunk(2, 1))
# --> 230 y.extend(m(y[-1]) for m in self.m)
#     231 return self.cv2(torch.cat(y, 1))
#
# File ~/anaconda3/envs/dev/lib/python3.9/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/dev/lib/python3.9/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/anaconda3/envs/dev/lib/python3.9/site-packages/ultralytics/nn/modules/block.py:340, in Bottleneck.forward(self, x)
#     338 def forward(self, x):
#     339     """'forward()' applies the YOLO FPN to input data."""
# --> 340     return x + self.cv2(self.cv1(x)) if self.add else self.cv2(self.cv1(x))
#
# File ~/anaconda3/envs/dev/lib/python3.9/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/dev/lib/python3.9/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/anaconda3/envs/dev/lib/python3.9/site-packages/ultralytics/nn/modules/conv.py:54, in Conv.forward_fuse(self, x)
#      52 def forward_fuse(self, x):
#      53     """Perform transposed convolution of 2D data."""
# ---> 54     return self.act(self.conv(x))
#
# File ~/anaconda3/envs/dev/lib/python3.9/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/dev/lib/python3.9/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/anaconda3/envs/dev/lib/python3.9/site-packages/torch/nn/modules/conv.py:460, in Conv2d.forward(self, input)
#     459 def forward(self, input: Tensor) -> Tensor:
# --> 460     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/anaconda3/envs/dev/lib/python3.9/site-packages/torch/nn/modules/conv.py:456, in Conv2d._conv_forward(self, input, weight, bias)
#     452 if self.padding_mode != 'zeros':
#     453     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     454                     weight, bias, self.stride,
#     455                     _pair(0), self.dilation, self.groups)
# --> 456 return F.conv2d(input, weight, bias, self.stride,
#     457                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:

# %%
filtered_view = filter_all_labels(mapped_view)

# %%
session = fo.launch_app(filtered_view, auto=False)

# %%
base_results = filtered_view.evaluate_detections("base_model", gt_field="ground_truth", eval_key="eval_base_model")
large_slice_results = filtered_view.evaluate_detections("large_slices", gt_field="ground_truth", eval_key="eval_large_slices")
small_slice_results = filtered_view.evaluate_detections("small_slices", gt_field="ground_truth", eval_key="eval_small_slices")

# %%
print("Base model results:")
base_results.print_report()

print("-" * 50)
print("Large slice results:")
large_slice_results.print_report()

print("-" * 50)
print("Small slice results:")
small_slice_results.print_report()

# %%
## Filtering for only small boxes

box_width, box_height = F("bounding_box")[2], F("bounding_box")[3]
rel_bbox_area = box_width * box_height

im_width, im_height = F("$metadata.width"), F("$metadata.height")
abs_area = rel_bbox_area * im_width * im_height

small_boxes_view = filtered_view
for lf in get_label_fields(filtered_view):
    small_boxes_view = small_boxes_view.filter_labels(lf, abs_area < 32**2, only_matches=False)

# %%
session.view = small_boxes_view.view()

# %%
small_boxes_base_results = small_boxes_view.evaluate_detections("base_model", gt_field="ground_truth", eval_key="eval_small_boxes_base_model")
small_boxes_large_slice_results = small_boxes_view.evaluate_detections("large_slices", gt_field="ground_truth", eval_key="eval_small_boxes_large_slices")
small_boxes_small_slice_results = small_boxes_view.evaluate_detections("small_slices", gt_field="ground_truth", eval_key="eval_small_boxes_small_slices")
